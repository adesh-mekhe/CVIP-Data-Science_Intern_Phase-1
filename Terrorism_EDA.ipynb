# %% [markdown]
# # **Exploratory Data Analysis - Terrorism**

# %% [markdown]
# Author: Adesh Mekhe

# %% [markdown]
# Dataset: https://bit.ly/2TK5Xn5

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # **Importing and observing the data**

# %%
data=pd.read_csv("/content/globalterrorismdb_0718dist.csv", encoding="latin1")
df=pd.DataFrame(data)
print("Data has been successfully imported")
df.head()
# Out:
# Data has been successfully imported
# <ipython-input-5-1a7ce99941f8>:1: DtypeWarning: Columns (4,31,33,76,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("/content/globalterrorismdb_0718dist.csv", encoding="latin1")
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN       0.0        NaN     58.0
# 1  197000000002   1970       0     0        NaN       0.0        NaN    130.0
# 2  197001000001   1970       1     0        NaN       0.0        NaN    160.0
# 3  197001000002   1970       1     0        NaN       0.0        NaN     78.0
# 4  197001000003   1970       1     0        NaN       0.0        NaN    101.0
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic     2.0  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico     1.0  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines     5.0  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece     8.0  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan     4.0  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
df.tail()
# Out:
#       Year  Month  Day    Country          Region Province/State  \
# 9651  1979     11   13  Argentina   South America   Buenos Aires
# 9652  1979     11   13   Colombia   South America        Unknown
# 9653  1979     11   13   Colombia   South America         Tolima
# 9654  1979     11   13   Portugal  Western Europe         Lisbon
# 9655  1979     11   14        NaN             NaN            NaN
#
#               City   Latitude  Longitude Location Summary  \
# 9651  Buenos Aires -34.617680 -58.444435      NaN     NaN
# 9652  Las Delicias        NaN        NaN      NaN     NaN
# 9653        Bilbao   3.273849 -75.746079      NaN     NaN
# 9654        Lisbon  38.725299  -9.150036      NaN     NaN
# 9655           NaN        NaN        NaN      NaN     NaN
#
#                       Attack Type                  Target Type  \
# 9651            Bombing/Explosion         Government (General)
# 9652                Armed Assault                       Police
# 9653                Armed Assault  Private Citizens & Property
# 9654  Hostage Taking (Kidnapping)      Government (Diplomatic)
# 9655                          NaN                          NaN
#
#                                          Group Name Motive Weapon Type  \
# 9651                         Montoneros (Argentina)    NaN    Firearms
# 9652  Revolutionary Armed Forces of Colombia (FARC)    NaN     Unknown
# 9653  Revolutionary Armed Forces of Colombia (FARC)    NaN    Firearms
# 9654                                        Unknown    NaN     Unknown
# 9655                                            NaN    NaN         NaN
#
#       Killed  Wounded Add Notes  Casualty
# 9651     4.0      0.0       NaN       4.0
# 9652     2.0      0.0       NaN       2.0
# 9653     0.0      0.0       NaN       0.0
# 9654     1.0      4.0       NaN       5.0
# 9655     0.0      0.0       NaN       0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9656 entries, 0 to 9655
# Columns: 135 entries, eventid to related
# dtypes: float64(77), int64(4), object(54)
# memory usage: 9.9+ MB

# %%
df.shape
# Out:
# (9656, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in df.columns:
    print(i,end=", ")
# Out:
# eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtype2, weapsubtype2_txt, weaptype3, weaptype3_txt, weapsubtype3, weapsubtype3_txt, weaptype4, weaptype4_txt, weapsubtype4, weapsubtype4_txt, weapdetail, nkill, nkillus, nkillter, nwound, nwoundus, nwoundte, property, propextent, propextent_txt, propvalue, propcomment, ishostkid, nhostkid, nhostkidus, nhours, ndays, divert, kidhijcountry, ransom, ransomamt, ransomamtus, ransompaid, ransompaidus, ransomnote, hostkidoutcome, hostkidoutcome_txt, nreleased, addnotes, scite1, scite2, scite3, dbsource, INT_LOG, INT_IDEO, INT_MISC, INT_ANY, related,

# %% [markdown]
# # **Cleaning the data**

# %%
df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                 gname motive weaptype1_txt  nkill  nwound  \
# 0                              MANO-D    NaN       Unknown    1.0     0.0
# 1  23rd of September Communist League    NaN       Unknown    0.0     0.0
# 2                             Unknown    NaN       Unknown    1.0     0.0
# 3                             Unknown    NaN    Explosives    NaN     NaN
# 4                             Unknown    NaN    Incendiary    NaN     NaN
#
#   addnotes
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack Type","targtype1_txt":"Target Type",
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                            Group Name Motive Weapon Type  Killed  Wounded  \
# 0                              MANO-D    NaN     Unknown     1.0      0.0
# 1  23rd of September Communist League    NaN     Unknown     0.0      0.0
# 2                             Unknown    NaN     Unknown     1.0      0.0
# 3                             Unknown    NaN  Explosives     NaN      NaN
# 4                             Unknown    NaN  Incendiary     NaN      NaN
#
#   Add Notes
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9656 entries, 0 to 9655
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            9656 non-null   int64
#  1   Month           9656 non-null   int64
#  2   Day             9656 non-null   int64
#  3   Country         9655 non-null   object
#  4   Region          9655 non-null   object
#  5   Province/State  9617 non-null   object
#  6   City            9655 non-null   object
#  7   Latitude        9353 non-null   float64
#  8   Longitude       9353 non-null   float64
#  9   Location        550 non-null    object
#  10  Summary         865 non-null    object
#  11  Attack Type     9655 non-null   object
#  12  Target Type     9655 non-null   object
#  13  Group Name      9655 non-null   object
#  14  Motive          601 non-null    object
#  15  Weapon Type     9655 non-null   object
#  16  Killed          8497 non-null   float64
#  17  Wounded         7214 non-null   float64
#  18  Add Notes       634 non-null    object
# dtypes: float64(4), int64(3), object(12)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (9656, 19)

# %%
df.isnull().sum()
# Out:
# Year                 0
# Month                0
# Day                  0
# Country              1
# Region               1
# Province/State      39
# City                 1
# Latitude           303
# Longitude          303
# Location          9106
# Summary           8791
# Attack Type          1
# Target Type          1
# Group Name           1
# Motive            9055
# Weapon Type          1
# Killed            1159
# Wounded           2442
# Add Notes         9022
# dtype: int64

# %%
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df["Casualty"]=df["Killed"]+df["Wounded"]

# %%
df.describe()
# Out:
#               Year        Month          Day     Latitude    Longitude  \
# count  9656.000000  9656.000000  9656.000000  9353.000000  9353.000000
# mean   1975.971935     6.282001    15.164561    33.155350   -20.829568
# std       2.890571     3.368098     9.022129    22.172133    53.255134
# min    1970.000000     0.000000     0.000000   -45.867889  -157.818968
# 25%    1974.000000     3.000000     7.000000    25.699073   -73.931351
# 50%    1977.000000     6.000000    15.000000    40.697132    -5.956210
# 75%    1978.000000     9.000000    23.000000    46.669097    11.119059
# max    1979.000000    12.000000    31.000000    64.837778   172.636225
#
#             Killed      Wounded     Casualty
# count  9656.000000  9656.000000  9656.000000
# mean      0.717585     0.811205     1.528790
# std       5.399032     6.241496     8.798474
# min       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     1.000000
# max     422.000000   285.000000   422.000000

# %% [markdown]
# # **Visualizing the data**

# %% [markdown]
# # Year wise Attacks

# %% [markdown]
# 1.Number of Attacks in each Year

# %%
attacks=df["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.head()
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %%
attacks.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# (i) Most number of attacks in 1979
#
# (ii) Least number of attacks in 1971

# %% [markdown]
# 2.Total Casualties (Killed + Wounded) in each Year

# %%
yc=df[["Year","Casualty"]].groupby("Year").sum()
yc.head()
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0

# %%
yc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Year wise Casualties",fontsize=13)
plt.xlabel("Years",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# 3.Killed in each Year

# %%
yk=df[["Year","Killed"]].groupby("Year").sum()
yk.head()
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %% [markdown]
# 4.Wounded in each Region

# %%
yw=df[["Year","Wounded"]].groupby("Year").sum()
yw.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#Killed
yk.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("People Killed in each Year")
ax0.set_xlabel("Years")
ax0.set_ylabel("Number of People Killed")

#Wounded
yw.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("People Wounded in each Year")
ax1.set_xlabel("Years")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %%
reg=pd.crosstab(df.Year,df.Region)
reg.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  East Asia  \
# Year
# 1970                        1                            7          2
# 1971                        1                            5          1
# 1972                        8                            3          0
# 1973                        1                            6          2
# 1974                        1                           11          4
#
# Region  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970                12                          28            472
# 1971                 5                          55            247
# 1972                 1                          53             73
# 1973                 1                          19             64
# 1974                 2                          42            111
#
# Region  South America  South Asia  Southeast Asia  Sub-Saharan Africa  \
# Year
# 1970               65           1              10                   3
# 1971               24           0               6                   2
# 1972               33           1              16                   4
# 1973               83           1               2                   4
# 1974               81           2               3                   7
#
# Region  Western Europe
# Year
# 1970                50
# 1971               125
# 1972               376
# 1973               290
# 1974               317

# %% [markdown]
# # Region Wise Attack

# %%
reg.plot(kind="area", stacked=False, alpha=0.5,figsize=(20,10))
plt.title("Region wise attacks",fontsize=20)
plt.xlabel("Years",fontsize=20)
plt.ylabel("Number of Attacks",fontsize=20)
plt.show()

# %% [markdown]
# # Country wise Attacks - Top 10

# %%
ct=df["Country"].value_counts().head(10)
ct
# Out:
# United Kingdom    1599
# United States     1460
# Italy              992
# Spain              890
# Turkey             475
# France             464
# Colombia           404
# El Salvador        387
# Argentina          326
# Nicaragua          286
# Name: Country, dtype: int64

# %%
ct.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Country wise Attacks",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()
